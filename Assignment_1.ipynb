# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("dataset_Facebook.csv" , delimiter =';')
data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
data.shape
# Out:
# (500, 19)

# %%
data.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
data.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
data1=data.dropna()

# %%
data1.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
sub1=data1[data1['Type']=='Photo']
sub1
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Photo         2          12             4          3
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 494             85093  Photo         3           1             7         10
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
#
# ...

# %%
sub2=data1[(data1["Paid"]==1) &(data1["Post Month"]>5)]
sub2
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 3              139441  Photo         2          12             2         10
# 6              139441  Photo         3          12             1          3
# 7              139441  Photo         3          12             7          9
# 14             138414  Photo         2          12             4          5
# 17             138414  Photo         1          12             2         12
# ..                ...    ...       ...         ...           ...        ...
# 313            124940  Photo         3           6             7          3
# 314            124940  Photo         1           6             6         12
# 319            123047  Photo         2           6             4          5
# 322            123047  Photo         3           6             2          5
# 324            123047  Photo         3           6             1          3
#
# ...

# %%
sub3=data1[(data1['Post Weekday']>2) | (data1['comment']<5)]
sub3
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 5              139441  Status         2          12             1          9
# 6              139441   Photo         3          12             1          3
# ..                ...     ...       ...         ...           ...        ...
# 494             85093   Photo         3           1             7         10
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
#
# ...

# %%
sub4=data1.iloc[:,1:6]
sub4
# Out:
#        Type  Category  Post Month  Post Weekday  Post Hour
# 0     Photo         2          12             4          3
# 1    Status         2          12             3         10
# 2     Photo         3          12             3          3
# 3     Photo         2          12             2         10
# 4     Photo         2          12             2          3
# ..      ...       ...         ...           ...        ...
# 494   Photo         3           1             7         10
# 495   Photo         3           1             7          2
# 496   Photo         2           1             5          8
# 497   Photo         1           1             5          2
# 498   Photo         3           1             4         11
#
# [495 rows x 5 columns]

# %%
merge_1=pd.concat([sub4,sub5])
merge_1
# Out:
#       Type  Category  Post Month  Post Weekday  Post Hour  Page total likes  \
# 0    Photo         2          12             4          3               NaN
# 1   Status         2          12             3         10               NaN
# 2    Photo         3          12             3          3               NaN
# 3    Photo         2          12             2         10               NaN
# 4    Photo         2          12             2          3               NaN
# ..     ...       ...         ...           ...        ...               ...
# 7    Photo         3          12             7          9          139441.0
# 8   Status         2          12             7          3          139441.0
# 9    Photo         3          12             6         10          139441.0
# 10  Status         2          12             5         10          139441.0
# 11   Photo         2          12             5         10          139441.0
#
# ...

# %%
sub7=data1.iloc[:,15:]

sub7
# Out:
#      comment    like  share  Total Interactions
# 0          4    79.0   17.0                 100
# 1          5   130.0   29.0                 164
# 2          0    66.0   14.0                  80
# 3         58  1572.0  147.0                1777
# 4         19   325.0   49.0                 393
# ..       ...     ...    ...                 ...
# 494       10   125.0   41.0                 176
# 495        5    53.0   26.0                  84
# 496        0    53.0   22.0                  75
# 497        4    93.0   18.0                 115
# 498        7    91.0   38.0                 136
#
# [495 rows x 4 columns]

# %%
sub6=data1[['Type','like','Category']]
sub6
# Out:
#        Type    like  Category
# 0     Photo    79.0         2
# 1    Status   130.0         2
# 2     Photo    66.0         3
# 3     Photo  1572.0         2
# 4     Photo   325.0         2
# ..      ...     ...       ...
# 494   Photo   125.0         3
# 495   Photo    53.0         3
# 496   Photo    53.0         2
# 497   Photo    93.0         1
# 498   Photo    91.0         3
#
# [495 rows x 3 columns]

# %%
merge_df2=pd.merge(sub6,sub7,on='like')
merge_df2
# Out:
#        Type  like  Category  comment  share  Total Interactions
# 0     Photo  79.0         2        4   17.0                 100
# 1     Photo  79.0         2        2   16.0                  97
# 2     Photo  79.0         2        1   17.0                  97
# 3     Photo  79.0         2        4   16.0                  99
# 4     Photo  79.0         2        5   11.0                  95
# ...     ...   ...       ...      ...    ...                 ...
# 1380  Photo  93.0         1        5   19.0                 117
# 1381  Photo  93.0         1        2   26.0                 121
# 1382  Photo  93.0         1        4   18.0                 115
# 1383  Photo  91.0         3        5   26.0                 122
# 1384  Photo  91.0         3        7   38.0                 136
#
# [1385 rows x 6 columns]

# %%
sort1=merge_df2.sort_values('Category')
sort1
# Out:
#        Type  like  Category  comment  share  Total Interactions
# 1279  Photo  79.0         1        2   16.0                  97
# 346   Photo   4.0         1        0    0.0                   4
# 345   Photo   4.0         1        0    1.0                   5
# 1382  Photo  93.0         1        4   18.0                 115
# 344   Photo   4.0         1        0    2.0                   6
# ...     ...   ...       ...      ...    ...                 ...
# 1371  Photo  53.0         3        3   13.0                  69
# 1383  Photo  91.0         3        5   26.0                 122
# 1384  Photo  91.0         3        7   38.0                 136
# 1372  Photo  53.0         3        5   26.0                  84
# 1373  Photo  53.0         3        0   22.0                  75
#
# [1385 rows x 6 columns]

# %%
sort2=merge_df2.sort_values('Total Interactions' ,ascending=False)
sort2
# Out:
#        Type    like  Category  comment  share  Total Interactions
# 652   Photo  5172.0         2      372  790.0                6334
# 1037  Photo  1998.0         3       51  128.0                2177
# 453   Photo  1622.0         1      144  208.0                1974
# 1277  Photo  1546.0         3      146  181.0                1873
# 959   Photo  1639.0         3       45  122.0                1806
# ...     ...     ...       ...      ...    ...                 ...
# 276   Photo     0.0         1        0    0.0                   0
# 59    Photo     0.0         1        0    0.0                   0
# 56    Photo     0.0         1        0    0.0                   0
# 58    Photo     0.0         1        0    0.0                   0
# 55    Photo     0.0         1        0    0.0                   0
#
# [1385 rows x 6 columns]

# %%
transpose1=sort2.transpose()
transpose1
# Out:
#                       652     1037    453     1277    959     13      278   \
# Type                 Photo   Photo   Photo   Photo   Photo   Photo   Photo
# like                5172.0  1998.0  1622.0  1546.0  1639.0  1572.0  1505.0
# Category                 2       3       1       3       3       2       2
# comment                372      51     144     146      45      58      26
# share                790.0   128.0   208.0   181.0   122.0   147.0    95.0
# Total Interactions    6334    2177    1974    1873    1806    1777    1626
#
#                       889     530     472   ...   220    1217   223    57    \
# Type                 Photo   Photo   Photo  ...  Photo  Photo  Photo  Photo
# like                1372.0  1155.0  1047.0  ...    0.0    0.0    0.0    0.0
# Category                 3       3       3  ...      1      1      1      1
# comment                 20      33      29  ...      0      0      0      0
# ...

# %%
merge_df2.duplicated(subset=['Type' ,'Category'])
# Out:
# 0       False
# 6       False
# 8       False
# 43      False
# 44      False
# 60      False
# 77      False
# 132     False
# 1168    False
# 1201    False
# dtype: bool

# %%
merge_df2=merge_df2.drop_duplicates(subset=['Type' ,'Category'])

merge_df2.pivot(index=['Type'] , columns=['Category'],values=['like'] )
# Out:
#            like
# Category      1      2     3
# Type
# Link       16.0   32.0  68.0
# Photo     678.0   79.0  66.0
# Status    174.0  130.0  54.0
# Video     143.0    NaN   NaN

# %%
sub3.pivot_table(index=['Type'] , columns=['Category'],values=['like'], aggfunc='sum')
# Out:
#              like
# Category        1        2        3
# Type
# Link       1513.0     32.0     68.0
# Photo     19236.0  17748.0  25055.0
# Status      409.0   6552.0    606.0
# Video      1071.0      NaN      NaN

# %%
melt1 = pd.melt(sub2 , id_vars=['Post Month'] , value_vars=["like","comment","share","Total Interactions"])
melt1
# Out:
#      Post Month            variable   value
# 0            12                like  1572.0
# 1            12                like   249.0
# 2            12                like   325.0
# 3            12                like   577.0
# 4            12                like   678.0
# ..          ...                 ...     ...
# 359           6  Total Interactions    82.0
# 360           6  Total Interactions    28.0
# 361           6  Total Interactions   235.0
# 362           6  Total Interactions    83.0
# 363           6  Total Interactions    65.0
#
# [364 rows x 3 columns]

# %%
import seaborn as sns

# %%
sns.pairplot(data1 ,hue='Category')

# %%
import matplotlib as plt

# %%
sns.barplot(data1 , x='Category' , y='Post Weekday')
# Out:
# <Axes: xlabel='Category', ylabel='Post Weekday'>

# %%
sns.scatterplot(data1, x="share",y="Total Interactions")
# Out:
# <Axes: xlabel='share', ylabel='Total Interactions'>

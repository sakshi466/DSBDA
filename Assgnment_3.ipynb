# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv("bank_data_set.csv")
data
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
data.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# deposit      0
# dtype: int64

# %%
sns.histplot(data["age"], bins=20, kde=True, color="orange", edgecolor="black", alpha=0.7, linewidth=1.2)
plt.title("Age Distribution", fontsize=14, fontweight="bold", color="darkred")
plt.xlabel("Age", fontsize=12)
plt.ylabel("Frequency", fontsize=12)

print ("Inference:The histogram show that the data is normally distributed, and the people in this dataset   have mostly age  between 30-40. This histogram displays the frequency of people falling within different age ranges on the standardized test. Each bar represents a age range, and the height of the bar represents the frequency of people's age  in that range")
# Out:
# Inference:The histogram show that the data is normally distributed, and the people in this dataset   have mostly age  between 30-40. This histogram displays the frequency of people falling within different age ranges on the standardized test. Each bar represents a age range, and the height of the bar represents the frequency of people's age  in that range

# %%
sns.scatterplot(data=data, x="marital", y="balance", color="red", edgecolor="black", s=80, marker="o")
plt.title("Eduaction vs Bank Balance", fontsize=14, fontweight="bold", color="darkblue")
plt.xlabel("Eduaction", fontsize=12)
plt.ylabel("Bank Balance", fontsize=12)
plt.show()
print ("Inference:The scatterplot It is generally used to plot the relationship between variables , where an one variable is plotted on the x-axis is marital and  another  plotted on the y-axis is balance , the graph show that people who are  marride  have more bank accounts  as compare to others ")
# Out:
# Inference:The scatterplot It is generally used to plot the relationship between variables , where an one variable is plotted on the x-axis is marital and  another  plotted on the y-axis is balance , the graph show that people who are  marride  have more bank accounts  as compare to others

# %%
colors = sns.color_palette("pastel")
plt.figure(figsize=(8, 8))
plt.pie(
    data["job"].value_counts(), 
    labels=data["job"].value_counts().index, 
    autopct="%1.1f%%", 
    colors=colors
)
plt.title("Distribution of Different Jobs Among Bank Customers", fontsize=14, fontweight="bold", color="darkblue")
plt.show()
print("Inference:A pie chart helps organize and show data as a percentage of a whole ,here it show that mostly banck customers are from management field ")
# Out:
# Inference:A pie chart helps organize and show data as a percentage of a whole ,here it show that mostly banck customers are from management field

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=data, x="education", y="balance", edgecolor="black",  linewidth=1.2)
plt.title("Education Level vs. Bank Balance", fontsize=14, fontweight="bold", color="darkred")
plt.xlabel("Education Level", fontsize=12)
plt.ylabel("Average Balance", fontsize=12)
plt.show()
print("Inference:A barplot is used to visually compare the values of a numeric variable across different categories of a categorical variable, here it shows that customers who have done tertiary eduation have more back balance as compare to customers who have done other types of eduaction ")
# Out:
# Inference:A barplot is used to visually compare the values of a numeric variable across different categories of a categorical variable, here it shows that customers who have done tertiary eduation have more back balance as compare to customers who have done other types of eduaction

# %%
sns.pairplot(data)
print("Inference:A pairplot is used to visualize the pairwise relationships between multiple numeric variables within a dataset,here two colums values  are compare with each other  ")
# Out:
# Inference:A pairplot is used to visualize the pairwise relationships between multiple numeric variables within a dataset,here two colums values  are compare with each other

# %%
plt.bar(data["loan"],data["balance"] )
plt.show()
print("Inference:People those who have high bank balance generaly don't take loan ")
# Out:
# Inference:People those who have high bank balance generaly don't take loan

# %%
data.hist(column='job' ,by='deposit',figsize=(8,5), rwidth=12,color="green")
print("Inference:The hist shows us that what is a chances of customer from each field can deposite money in bank , the customers from admin and management field have nearly same chances of depositing and not depositing money but the students have high chances of deposit , entrepreneur generally don't deposite money ")
plt.show()
# Out:
# Inference:The hist shows us that what is a chances of customer from each field can deposite money in bank , the customers from admin and management field have nearly same chances of depositing and not depositing money but the students have high chances of deposit , entrepreneur generally don't deposite money

# %%
sns.scatterplot(data=data,x="duration",y="age")
print("Inference:The duration of an activity  does not significantly depend on age")
plt.show()
# Out:
# Inference:The duration of an activity  does not significantly depend on age

# %%
sns.kdeplot(data=data, x="balance", hue="loan")
print("Inference:People with higher balances are less likely to have loans (possibly because they don’t need one).There are a few high-balance customers, but they are very rare")
plt.show()
# Out:
# Inference:People with higher balances are less likely to have loans (possibly because they don’t need one).There are a few high-balance customers, but they are very rare

# %%
plt.figure(figsize=(8, 8))
plt.pie(
    data["education"].value_counts(), 
    labels=data["education"].value_counts().index, 
    autopct="%1.1f%%", 
    
)
plt.title("Distribution of Different Education Type", fontsize=14, fontweight="bold", color="darkblue")
plt.show()

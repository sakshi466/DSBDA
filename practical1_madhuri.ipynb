# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("dataset_Facebook(1).csv", sep= ";")

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
df.isna().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df2=df.dropna()

# %%
df2.isna().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
sub1=df2[df2['Type']=="Photo"]
sub1
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Photo         2          12             4          3
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 494             85093  Photo         3           1             7         10
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
#
# ...

# %%
sub2=df2[(df2['Paid']==1)&(df2['Post Month']>5)]
sub2
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 3              139441  Photo         2          12             2         10
# 6              139441  Photo         3          12             1          3
# 7              139441  Photo         3          12             7          9
# 14             138414  Photo         2          12             4          5
# 17             138414  Photo         1          12             2         12
# ..                ...    ...       ...         ...           ...        ...
# 313            124940  Photo         3           6             7          3
# 314            124940  Photo         1           6             6         12
# 319            123047  Photo         2           6             4          5
# 322            123047  Photo         3           6             2          5
# 324            123047  Photo         3           6             1          3
#
# ...

# %%
sub3=df2[df2['Page total likes']>100000]
sub3
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 433            100732   Photo         1           3             6         17
# 434            100732   Photo         1           3             6         15
# 435            100732   Photo         1           3             6         15
# 436            100732   Photo         1           3             6         13
# 437            100732   Photo         1           3             6         10
#
# ...

# %%
sub4=df2[(df2['Lifetime Post Consumers'])|(df2['Lifetime Post Total Reach']>10000)]
sub4
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 494             85093   Photo         3           1             7         10
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
#
# ...

# %%
sub5=df2[(df2['like']>500)&(df2['share']<50)]
sub5
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 14             138414  Photo         2          12             4          5
# 17             138414  Photo         1          12             2         12
# 191            133679  Photo         3           8             1         10
# 270            128032  Photo         2           7             4          5
# 272            127082  Photo         1           7             3          3
# 323            123047  Photo         3           6             1         10
# 476             86909  Photo         1           1             6         10
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 14    1.0                      22784                            39941
# 17    1.0                      53264                           111785
# 191   0.0                      19648                            33643
# 270   1.0                      53056                            65260
# ...

# %%
sub6=df2.iloc[:,15:]
sub6
# Out:
#      comment    like  share  Total Interactions
# 0          4    79.0   17.0                 100
# 1          5   130.0   29.0                 164
# 2          0    66.0   14.0                  80
# 3         58  1572.0  147.0                1777
# 4         19   325.0   49.0                 393
# ..       ...     ...    ...                 ...
# 494       10   125.0   41.0                 176
# 495        5    53.0   26.0                  84
# 496        0    53.0   22.0                  75
# 497        4    93.0   18.0                 115
# 498        7    91.0   38.0                 136
#
# [495 rows x 4 columns]

# %%
sub7=df2.iloc[0:120,:]
sub7
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 116            136642   Photo         1          10             7         12
# 117            136642   Photo         1          10             7         11
# 118            136642   Photo         1          10             7         10
# 119            136393   Photo         1          10             7         10
# 121            136393  Status         2          10             7          9
#
# ...

# %%
sub8=df2[['like','Type','Category']]
sub8
# Out:
#        like    Type  Category
# 0      79.0   Photo         2
# 1     130.0  Status         2
# 2      66.0   Photo         3
# 3    1572.0   Photo         2
# 4     325.0   Photo         2
# ..      ...     ...       ...
# 494   125.0   Photo         3
# 495    53.0   Photo         3
# 496    53.0   Photo         2
# 497    93.0   Photo         1
# 498    91.0   Photo         3
#
# [495 rows x 3 columns]

# %%
#merge

# %%
merged_df1 = pd.concat([sub3,sub5])
merged_df1
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 191            133679   Photo         3           8             1         10
# 270            128032   Photo         2           7             4          5
# 272            127082   Photo         1           7             3          3
# 323            123047   Photo         3           6             1         10
# 476             86909   Photo         1           1             6         10
#
# ...

# %%
sub2=df2.loc[df2['Type']=='Photo', [ 'Type', 'Category', 'Post Month', 'Post Weekday', 'Post Hour', 'Paid', 'comment', 'like', 'share']]

# %%
sub3=df2.loc[df2['Type']=='Photo', ['Type', 'Category', 'Post Month', 'Post Weekday', 'Post Hour', 'Paid']]

# %%
merged1 = pd.merge(sub2, sub3, how="inner")

# %%
sub4=df2.loc[50:100, ['Type', 'Category', 'Post Month', 'Post Weekday', 'Post Hour', 'Paid']]

# %%
sub5=df2.loc[101:200,  ['Type', 'Category', 'Post Month', 'Post Weekday', 'Post Hour', 'Paid']]

# %%
merged2=pd.merge(sub4, sub5, how='outer')

# %%
merged2
# Out:
#        Type  Category  Post Month  Post Weekday  Post Hour  Paid
# 0      Link         1          10             4          3   0.0
# 1      Link         1          10             5         10   0.0
# 2      Link         1          10             6         11   1.0
# 3      Link         1          11             4          3   0.0
# 4     Photo         1           8             4          9   1.0
# ..      ...       ...         ...           ...        ...   ...
# 140  Status         3          11             5          2   0.0
# 141   Video         1           9             2         10   0.0
# 142   Video         1          11             3         11   0.0
# 143   Video         1          11             5          3   1.0
# 144   Video         1          11             6          2   1.0
#
# [145 rows x 6 columns]

# %%
#sort

# %%
sort2=df2.sort_values('like',ascending=False)
sort2
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 379            111620  Photo         3           4             1         14
# 349            117764  Photo         3           5             5         13
# 168            135428  Photo         1           9             3         10
# 3              139441  Photo         2          12             2         10
# ..                ...    ...       ...         ...           ...        ...
# 21             138414  Photo         1          12             7         10
# 100            137020  Photo         1          10             4          9
# 441             98195  Photo         1           3             5          4
# 76             137893  Photo         1          11             3          2
# 417            104070  Photo         1           3             3         10
#
# ...

# %%
transpose_df=df2.transpose()
transpose_df
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
df2.shape
# Out:
# (495, 19)

# %%
df2
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 494             85093   Photo         3           1             7         10
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
#
# ...

# %%
d1 = df2[df2["Paid"] == 1]

# %%
pivot_df=pd.pivot_table(df2,index="Post Month",columns="Paid",values="like",aggfunc="sum")
pivot_df
# Out:
# Paid           0.0     1.0
# Post Month
# 1           2227.0   754.0
# 2           3901.0  1116.0
# 3           2227.0   765.0
# 4           3595.0  5542.0
# 5           6730.0  1268.0
# 6           5060.0  1487.0
# 7           5836.0  8335.0
# 8           5423.0  1324.0
# 9           5644.0  2652.0
# 10          6966.0  2264.0
# 11          3597.0  3355.0
# 12          4716.0  3893.0

# %%
df2
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 494             85093   Photo         3           1             7         10
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
#
# ...

# %%
sort3=df.sort_values("like")
sort3
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 76             137893  Photo         1          11             3          2
# 100            137020  Photo         1          10             4          9
# 441             98195  Photo         1           3             5          4
# 417            104070  Photo         1           3             3         10
# 21             138414  Photo         1          12             7         10
# ..                ...    ...       ...         ...           ...        ...
# 168            135428  Photo         1           9             3         10
# 349            117764  Photo         3           5             5         13
# 379            111620  Photo         3           4             1         14
# 244            130791  Photo         2           7             3          5
# 111            136736  Photo         1          10             6          8
#
# ...

# %%
pivot_df=pd.pivot_table(df2,index="Post Month",columns="Paid",values="like")

# %%
pivot_df
# Out:
# Paid               0.0         1.0
# Post Month
# 1           111.350000  188.500000
# 2           216.722222  139.500000
# 3            79.535714   95.625000
# 4           119.833333  277.100000
# 5           232.068966  158.500000
# 6           140.555556  114.384615
# 7           182.375000  416.750000
# 8           225.958333  132.400000
# 9           235.166667  241.090909
# 10          154.800000  188.666667
# 11          119.900000  223.666667
# 12          117.900000  389.300000

# %%
import seaborn as sns

# %%
#sns.pairplot(df2,hue="Category")

# %%
sub = df[0:40]
sub
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0             139441   Photo         2          12             4          3
# 1             139441  Status         2          12             3         10
# 2             139441   Photo         3          12             3          3
# 3             139441   Photo         2          12             2         10
# 4             139441   Photo         2          12             2          3
# 5             139441  Status         2          12             1          9
# 6             139441   Photo         3          12             1          3
# 7             139441   Photo         3          12             7          9
# 8             139441  Status         2          12             7          3
# 9             139441   Photo         3          12             6         10
# 10            139441  Status         2          12             5         10
# ...

# %%
melt_function=pd.melt(sub,id_vars=["Paid"],value_vars=["like","comment","share","Total Interactions","Page total likes","Lifetime Post Total Reach"])
melt_function
# Out:
#      Paid                   variable    value
# 0     0.0                       like     79.0
# 1     0.0                       like    130.0
# 2     0.0                       like     66.0
# 3     1.0                       like   1572.0
# 4     0.0                       like    325.0
# ..    ...                        ...      ...
# 235   0.0  Lifetime Post Total Reach   4512.0
# 236   0.0  Lifetime Post Total Reach   2690.0
# 237   1.0  Lifetime Post Total Reach  19800.0
# 238   0.0  Lifetime Post Total Reach  17576.0
# 239   0.0  Lifetime Post Total Reach   3290.0
#
# [240 rows x 3 columns]

# %%
sub.shape
# Out:
# (40, 19)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("bank_data_set.csv")

# %%
df
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
df.isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# deposit      0
# dtype: int64

# %% [markdown]
# # Scatterplot

# %%
sns.scatterplot(df,x='age',y='balance',hue=df['deposit'], palette="coolwarm")
# Out:
# <Axes: xlabel='age', ylabel='balance'>

# %% [markdown]
# As per shown in above graph which indicates Duration vs Balance we can say  that when people are not deposites the money in the bank at that time at that
# time there balance is generally less than 10000.

# %% [markdown]
# # Voilinplot

# %%
sns.catplot(df, x="loan", y="age",kind="violin")
plt.title("Age Distribution of Customers")
# Out:
# Text(0.5, 1.0, 'Age Distribution of Customers')

# %% [markdown]
#  Basically voilinplot is use to show the frequency of data. In above graph we plot graph for Loan vs Age .
#  In above graph If the width of the violin plot is wider at a certain age range, it means more customers fall in that age group.And it concludes that if younger customers dominate the loan = Yes category, it might suggest younger
#  people need more financial support.

# %% [markdown]
# # Histplot

# %%
sns.histplot(df['age'], bins=20, kde=True, color='skyblue')
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Age Distribution of Customers")
plt.show()

# %% [markdown]
# In above Histplot we plot graph for Age vs Count. Means here it shows that how many number of Customers are belongs
# to that perticular age group.We can conclude that most number of accout holders are belong to 25 to 45 years old.

# %%
count1=df['age'].value_counts()
count1
# Out:
# age
# 31    496
# 32    477
# 34    466
# 33    464
# 35    461
#      ...
# 92      2
# 88      2
# 93      2
# 95      1
# 89      1
# Name: count, Length: 76, dtype: int64

# %% [markdown]
# # Distplot

# %%
sns.displot(df, x="age", col="deposit", row="loan",facet_kws=dict(margin_titles=True))

# %% [markdown]
# In above Displot is shows that when customer has deposit or not at that time is customer having any loan or not.We can conclude that when customer has no loan at that time he has not deposit as compare to he has deposit.But when customer has loan at that time he has generally not having deposit in there bank account

# %% [markdown]
# # Barplot

# %%
plt.figure(figsize=(15,9))
sns.barplot(x='job', y='balance', data=df)
# Out:
# <Axes: xlabel='job', ylabel='balance'>

# %% [markdown]
#  In above barplot we calculate the average balance of all the customers who having different types of jobs.

# %% [markdown]
# # Countplot

# %%
plt.figure(figsize=(15,9))
sns.countplot(x=df['job'], order=df['job'].value_counts().index)
# Out:
# <Axes: xlabel='job', ylabel='count'>

# %% [markdown]
# In above graph we can calculate how many customers are belongs to different
# types of jobs.By analyzing above graph we can conclude that there are lot of
# costomers who belong to management,blue-collar and technician profile

# %%
count2=df['deposit'].value_counts()
count2
# Out:
# deposit
# no     5873
# yes    5289
# Name: count, dtype: int64

# %% [markdown]
# # Pie Chart

# %%
count2.plot.pie(autopct="%1.1f%%", labels=["No","Yes"], colors=["red", "skyblue"])
plt.title("Deposit Distribution in Dataset")
plt.show()

# %% [markdown]
#  By using the above pie chart we can conclude that there are 52% customers
#  who don't have deposits in the bank

# %%
count4=df['poutcome'].value_counts()

# %% [markdown]
# # Pie Chart

# %%
count4.plot.pie(autopct='%1.1f%%')
plt.title("Distribution of outcome of the previous marketing campaign")
# Out:
# Text(0.5, 1.0, 'Distribution of outcome of the previous marketing campaign')

# %% [markdown]
#  By ploting the pie chart we can conclude the outcome of previouse marketing
#  compaigns.There is large percentage that shows that outcome is unknown and
# failure is 11% and success is 9.6%

# %% [markdown]
# # Stripplot

# %%
sns.stripplot(data=df, x="balance", y="job",hue="housing")
# Out:
# <Axes: xlabel='balance', ylabel='job'>

# %% [markdown]
# In this stripplot we plot graph for balance vs job and we check wheather those custometers having any housing loan or not.
# We can conclude that the customers who having jobs like Blue-collar,technicians and admin generally they are taking
#  the houding loan.

# %%
count3=df["housing"].value_counts()

# %% [markdown]
# # Joint Plot

# %%
sns.jointplot(data=df, x="age", y="duration", hue="housing", kind="kde")

# %% [markdown]
# In above HistPlot of Age vs Duration.We can conclude that

# %% [markdown]
# # Histplot

# %%
sns.histplot(df, x="duration", hue="deposit")
# Out:
# <Axes: xlabel='duration', ylabel='Count'>

# %% [markdown]
# In this Histplot which is based on duration,we can conclude that when customer lastly contact to bank is less than
# 400 at that time customer deposits the money .but when duration is greater than 400 at that time customer doesn't
# deposits the menoy
